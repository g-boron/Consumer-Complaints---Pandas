# %% [markdown]
# # Consumer Complaint Database

# %% [markdown]
# ## The Consumer Complaint Database is a collection of complaints about consumer financial products and services that we sent to companies for response. Complaints are published after the company responds, confirming a commercial relationship with the consumer, or after 15 days, whichever comes first. Complaints referred to other regulators, such as complaints about depository institutions with less than 10 billion dollars in assets, are not published in the Consumer Complaint Database. The database generally updates daily.

# %% [markdown]
# | Column | Description |
# |---|---|
# |Date received|The date when the consumer complaint was received.|
# |Product|The specific financial product or service associated with the complaint.|
# |Sub-product|Further sub-categorization of the product or service, if applicable.|
# |Issue|The main issue or problem described in the consumer complaint.|
# |Sub-issue|Additional details or sub-category related to the main issue.|
# |Consumer complaint narrative|The text description provided by the consumer detailing their complaint.|
# |Company public response|The response or statement issued by the company regarding the complaint.|
# |Company|The name of the company being complained about.|
# |State|The state where the consumer resides.|
# |ZIP Code|The ZIP code of the consumer's location.|
# |Tags|Any additional tags or labels associated with the complaint.|
# |Consumer consent provided?|Indicates whether the consumer provided consent for their complaint to be published.|
# |Submitted via|The channel or method through which the complaint was submitted.|
# |Date sent to company|The date when the complaint was sent to the company for response.|
# |Company response to consumer|The company's response or resolution to the consumer's complaint.|
# |Timely response?|Indicates whether the company provided a timely response to the complaint.|
# |Consumer disputed?|Indicates whether the consumer disputed the company's response.|
# |Complaint ID|A unique identifier assigned to each complaint.|

# %% [markdown]
# ## Dataset contains over 3.5 million rows

# %% [markdown]
# #### Source: https://www.kaggle.com/datasets/utkarshx27/consumer-complaint

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
complaints = pd.read_csv('./Files/complaints.csv', low_memory=False)

# %%
complaints.head()
# Out:
#   Date received                                            Product  \
# 0    2023-04-27  Credit reporting, credit repair services, or o...
# 1    2023-04-27  Credit reporting, credit repair services, or o...
# 2    2023-04-27  Credit reporting, credit repair services, or o...
# 3    2023-04-27  Credit reporting, credit repair services, or o...
# 4    2023-04-27  Credit reporting, credit repair services, or o...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting               Incorrect information on your report
# 1  Credit reporting               Incorrect information on your report
# 2  Credit reporting  Problem with a credit reporting company's inve...
# 3  Credit reporting               Incorrect information on your report
# 4  Credit reporting                        Improper use of your report
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# ...

# %%
complaints.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585952 entries, 0 to 3585951
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# ...

# %% [markdown]
# ### 1.Number of unique products

# %%
complaints['Product'].nunique()
# Out:
# 18

# %% [markdown]
# ### 2.Top 10 issues

# %%
complaints['Issue'].value_counts()[0:10]
# Out:
# Incorrect information on your report                                                895804
# Problem with a credit reporting company's investigation into an existing problem    485998
# Improper use of your report                                                         410423
# Attempts to collect debt not owed                                                   167770
# Loan modification,collection,foreclosure                                            112306
# Incorrect information on credit report                                              102684
# Managing an account                                                                 101232
# Loan servicing, payments, escrow account                                             77329
# Written notification about debt                                                      74456
# Trouble during payment process                                                       69404
# Name: Issue, dtype: int64

# %% [markdown]
# ### 3.Top 5 companies with the most issues

# %%
complaints = pd.read_csv('./Files/complaints.csv', low_memory=False)

# %%
complaints.head()
# Out:
#   Date received                                            Product  \
# 0    2023-04-27  Credit reporting, credit repair services, or o...
# 1    2023-04-27  Credit reporting, credit repair services, or o...
# 2    2023-04-27  Credit reporting, credit repair services, or o...
# 3    2023-04-27  Credit reporting, credit repair services, or o...
# 4    2023-04-27  Credit reporting, credit repair services, or o...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting               Incorrect information on your report
# 1  Credit reporting               Incorrect information on your report
# 2  Credit reporting  Problem with a credit reporting company's inve...
# 3  Credit reporting               Incorrect information on your report
# 4  Credit reporting                        Improper use of your report
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# ...

# %%
complaints.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585952 entries, 0 to 3585951
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# ...

# %%
companies_issues = complaints[['Date received', 'Issue', 'Company']]

# %%
companies_issues.shape
# Out:
# (3585952, 3)

# %%
top5 = companies_issues.pivot_table(index='Company', values='Issue', aggfunc='count').sort_values('Issue', ascending=False)[0:5]

# %%
for company in top5.index:
    print(company)
# Out:
# EQUIFAX, INC.
# TRANSUNION INTERMEDIATE HOLDINGS, INC.
# Experian Information Solutions Inc.
# BANK OF AMERICA, NATIONAL ASSOCIATION
# WELLS FARGO & COMPANY

# %% [markdown]
# ### 4.Chart showing number of issues in every state

# %%
issues_in_state = complaints[['Date received', 'Issue', 'State']]

# %%
issues_in_state.head()
# Out:
#   Date received                                              Issue State
# 0    2023-04-27               Incorrect information on your report    GA
# 1    2023-04-27               Incorrect information on your report    PA
# 2    2023-04-27  Problem with a credit reporting company's inve...    PA
# 3    2023-04-27               Incorrect information on your report    TX
# 4    2023-04-27                        Improper use of your report    NY

# %%
states = issues_in_state.groupby(by='State')

# %%
states.head()
# Out:
#         Date received                                              Issue State
# 0          2023-04-27               Incorrect information on your report    GA
# 1          2023-04-27               Incorrect information on your report    PA
# 2          2023-04-27  Problem with a credit reporting company's inve...    PA
# 3          2023-04-27               Incorrect information on your report    TX
# 4          2023-04-27                        Improper use of your report    NY
# ...               ...                                                ...   ...
# 657765     2016-03-09            Account opening, closing, or management    AS
# 672815     2020-01-20                            Trouble using your card    AS
# 1173831    2014-07-24                                Can't repay my loan    PW
# 1327427    2013-03-26             Incorrect information on credit report    PW
# 1737373    2016-05-05           Loan servicing, payments, escrow account    PW
#
# [315 rows x 3 columns]

# %%
states = states.agg({'Issue': 'count'})

# %%
states.head()
# Out:
#        Issue
# State
# AA        55
# AE      1047
# AK      3140
# AL     67337
# AP       618

# %%
states.plot(kind='bar', figsize=(15,8), title='Number of issues in every state', ylabel='Number of issues')
# Out:
# <Axes: title={'center': 'Number of issues in every state'}, xlabel='State', ylabel='Number of issues'>

# %% [markdown]
# ### 5.Find company which has the most percentage of timely reponses

# %%
complaints.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
complaints['Timely response?'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
timely_responses = complaints[['Company', 'Complaint ID', 'Timely response?']]

# %%
timely_responses.head()
# Out:
#          Company  Complaint ID Timely response?
# 0  EQUIFAX, INC.       6896105              Yes
# 1  EQUIFAX, INC.       6896026              Yes
# 2  EQUIFAX, INC.       6896030              Yes
# 3  EQUIFAX, INC.       6896035              Yes
# 4  EQUIFAX, INC.       6896060              Yes

# %%
responses_pivot = timely_responses.pivot_table(index='Company', columns='Timely response?', values='Complaint ID', aggfunc='count')

# %%
responses_pivot.head()
# Out:
# Timely response?                            No  Yes
# Company
# (Former)Shapiro, Swertfeger & Hasty, LLP  12.0  NaN
# 1 Auto Finance, Inc.                       3.0  NaN
# 1 STOP MONEY CENTERS, LLC                  2.0  7.0
# 10 Cent Title Pawn Inc                     NaN  2.0
# 16 Hands LLC. dba Fiducius                 NaN  1.0

# %% [markdown]
# #### Verification if data is correct

# %%
company_name = complaints['Company'] == '(Former)Shapiro, Swertfeger & Hasty, LLP'
time_response = complaints['Timely response?'] == 'Yes'
len(complaints.loc[company_name & time_response])
# Out:
# 0

# %%
responses_pivot.fillna(0, inplace=True)

# %%
responses_pivot.head()
# Out:
# Timely response?                            No  Yes
# Company
# (Former)Shapiro, Swertfeger & Hasty, LLP  12.0  0.0
# 1 Auto Finance, Inc.                       3.0  0.0
# 1 STOP MONEY CENTERS, LLC                  2.0  7.0
# 10 Cent Title Pawn Inc                     0.0  2.0
# 16 Hands LLC. dba Fiducius                 0.0  1.0

# %%
responses_pivot['Percentage'] = round(responses_pivot['Yes'] / (responses_pivot['Yes'] + responses_pivot['No']) * 100, 2)

# %%
responses_pivot.head(15)
# Out:
# Timely response?                               No   Yes  Percentage
# Company
# (Former)Shapiro, Swertfeger & Hasty, LLP     12.0   0.0        0.00
# 1 Auto Finance, Inc.                          3.0   0.0        0.00
# 1 STOP MONEY CENTERS, LLC                     2.0   7.0       77.78
# 10 Cent Title Pawn Inc                        0.0   2.0      100.00
# 16 Hands LLC. dba Fiducius                    0.0   1.0      100.00
# 1803 Capital, LLC                             1.0   4.0       80.00
# 1ST 2ND MORTGAGE CO. OF NJ INC                1.0   1.0       50.00
# 1ST ALLIANCE LENDING, LLC                     8.0  16.0       66.67
# 1ST CHOICE LOANS, LLC.                        0.0   1.0      100.00
# 1ST FINANCIAL, INC.                           2.0   6.0       75.00
# 1ST IBERIA CREDIT, INC.                       0.0   1.0      100.00
# 1ST PREFERENCE MORTGAGE CORP                  0.0   3.0      100.00
# 1ST RESULTS BILLINGS & COLLECTIONS, INC.      0.0   5.0      100.00
# ...

# %%
percentage_100 = responses_pivot['Percentage'] == 100
highest_percentage_companies = responses_pivot.loc[percentage_100]
highest_percentage_companies = highest_percentage_companies.sort_values('Yes', ascending=False)

# %%
highest_percentage_companies.head(1)
# Out:
# Timely response?   No     Yes  Percentage
# Company
# AFNI INC.         0.0  4652.0       100.0

# %% [markdown]
# ### 6.Top 5 most common sub-products

# %%
complaints['Sub-product'].value_counts().head(5)
# Out:
# Credit reporting                              1799698
# Checking account                               189415
# General-purpose credit card or charge card     141984
# I do not know                                  106045
# Other debt                                      92571
# Name: Sub-product, dtype: int64

# %% [markdown]
# ### 7.Pie chart showing share of reported complaints for different categories of products

# %%
complaints.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
complaints['Product'].value_counts()
# Out:
# Credit reporting, credit repair services, or other personal consumer reports    1818598
# Debt collection                                                                  479953
# Mortgage                                                                         375911
# Credit card or prepaid card                                                      186022
# Checking or savings account                                                      163721
# Credit reporting                                                                 140429
# Credit card                                                                       89190
# Bank account or service                                                           86205
# Student loan                                                                      74162
# Money transfer, virtual currency, or money service                                53522
# Vehicle loan or lease                                                             42919
# ...

# %%
complaints_share = complaints[['Product', 'Issue']]

# %%
complaints_share.head()
# Out:
#                                              Product  \
# 0  Credit reporting, credit repair services, or o...
# 1  Credit reporting, credit repair services, or o...
# 2  Credit reporting, credit repair services, or o...
# 3  Credit reporting, credit repair services, or o...
# 4  Credit reporting, credit repair services, or o...
#
#                                                Issue
# 0               Incorrect information on your report
# 1               Incorrect information on your report
# 2  Problem with a credit reporting company's inve...
# 3               Incorrect information on your report
# 4                        Improper use of your report

# %%
complaints_share_gr = complaints_share.groupby(by='Product')

# %%
complaints_share_gr = complaints_share_gr.agg('count')

# %%
complaints_share_gr.head()
# Out:
#                               Issue
# Product
# Bank account or service       86205
# Checking or savings account  163721
# Consumer Loan                 31575
# Credit card                   89190
# Credit card or prepaid card  186022

# %%
complaints_share_gr.plot.pie(y='Issue', figsize=(20,20), textprops={'fontsize': 15}, title='Share of reported complaints for each category')
# Out:
# <Axes: title={'center': 'Share of reported complaints for each category'}, ylabel='Issue'>

# %% [markdown]
# ### 8.Percentage of complaintes that was marked as 'Consumer disputed'

# %%
consumer_disputed_df = complaints[['Complaint ID', 'Consumer disputed?']]

# %%
consumer_disputed = consumer_disputed_df['Consumer disputed?'] == 'Yes'

# %%
round(len(consumer_disputed_df.loc[consumer_disputed]) / consumer_disputed_df.shape[0] * 100, 2)
# Out:
# 4.14

# %% [markdown]
# ### 9.Most used tag

# %%
complaints['Tags'].value_counts().index[0]
# Out:
# 'Servicemember'

# %% [markdown]
# #### What was the value of this tag?

# %%
complaints['Tags'].value_counts()[0]
# Out:
# 222932

# %% [markdown]
# ### 10.Compare distribution of reported complaints on different channels

# %%
complaints_distribution = complaints[['Complaint ID', 'Submitted via']]

# %%
complaints_distribution.head()
# Out:
#    Complaint ID Submitted via
# 0       6896105           Web
# 1       6896026           Web
# 2       6896030           Web
# 3       6896035           Web
# 4       6896060           Web

# %%
complaints_distribution_gr = complaints_distribution.groupby('Submitted via')

# %%
complaints_distribution_gr = complaints_distribution_gr.agg('count')

# %%
complaints_distribution_gr
# Out:
#                Complaint ID
# Submitted via
# Email                   425
# Fax                   25658
# Phone                156681
# Postal mail           88455
# Referral             240473
# Web                 3073419
# Web Referral            841

# %%
complaints_distribution_gr.plot.pie(y='Complaint ID', figsize=(20,20), explode=(0,0,0,0,0,0,0.1))
# Out:
# <Axes: ylabel='Complaint ID'>

# %% [markdown]
# ### 11.Find the company that gave public responses to the most complaints

# %%
complaints['Company public response'].value_counts()
# Out:
# Company has responded to the consumer and the CFPB and chooses not to provide a public response                            1386092
# Company believes it acted appropriately as authorized by contract or law                                                    120175
# Company chooses not to provide a public response                                                                             52473
# Company believes the complaint is the result of a misunderstanding                                                           11807
# Company disputes the facts presented in the complaint                                                                         9523
# Company believes complaint caused principally by actions of third party outside the control or direction of the company       7258
# Company believes complaint is the result of an isolated error                                                                 5775
# ...

# %%
not_public_response = complaints['Company public response'].isin(['Company has responded to the consumer and the CFPB and chooses not to provide a public response', 'Company chooses not to provide a public response'])

# %%
only_public_responses = complaints[['Company', 'Company public response']]

# %%
only_public_responses = only_public_responses[~not_public_response]

# %%
only_public_responses.head()
# Out:
#          Company Company public response
# 0  EQUIFAX, INC.                     NaN
# 1  EQUIFAX, INC.                     NaN
# 2  EQUIFAX, INC.                     NaN
# 3  EQUIFAX, INC.                     NaN
# 4  EQUIFAX, INC.                     NaN

# %%
only_public_responses = only_public_responses.dropna(subset='Company public response')

# %%
only_public_responses.head()
# Out:
#                                Company  \
# 93     Atlanticus Services Corporation
# 112                The CMI Group, Inc.
# 343   Amsher Collection Services, Inc.
# 1021          Shellpoint Partners, LLC
# 1150              Clear Recovery, Inc.
#
#                                 Company public response
# 93    Company believes it acted appropriately as aut...
# 112   Company believes it acted appropriately as aut...
# 343   Company believes it acted appropriately as aut...
# 1021  Company believes complaint is the result of an...
# 1150  Company believes it acted appropriately as aut...

# %%
only_public_responses_gr = only_public_responses.groupby(by='Company')

# %%
only_public_responses_gr = only_public_responses_gr.agg('count').sort_values(by='Company public response', ascending=False)

# %%
only_public_responses_gr.head(1)
# Out:
#                            Company public response
# Company
# NAVY FEDERAL CREDIT UNION                    12032

# %%
only_public_responses_gr.head(1).index[0]
# Out:
# 'NAVY FEDERAL CREDIT UNION'

# %% [markdown]
# ### 12.Chart showing number of complaints in order of date received between 2011-12-01 and 2012-12-01

# %%
complaints_in_days = complaints[['Date received', 'Complaint ID']]

# %%
complaints_in_days.head()
# Out:
#   Date received  Complaint ID
# 0    2023-04-27       6896105
# 1    2023-04-27       6896026
# 2    2023-04-27       6896030
# 3    2023-04-27       6896035
# 4    2023-04-27       6896060

# %%
complaints_in_days_gr = complaints_in_days.groupby('Date received').agg('count')

# %%
complaints_in_days_gr['2011-12-01':'2012-12-02'].plot(figsize=(15,5), title='Number of complaints between 2011-12-01 and 2012-12-01', ylabel='Number of complaints', color='green', grid=True)
# Out:
# <Axes: title={'center': 'Number of complaints between 2011-12-01 and 2012-12-01'}, xlabel='Date received', ylabel='Number of complaints'>

# %% [markdown]
# ### 12a. Between last 365 days

# %%
complaints_in_days_gr[-365:].plot(figsize=(15,5), title='Number of complaints in last 365 days', ylabel='Number of complaints', color='red', grid=True)
# Out:
# <Axes: title={'center': 'Number of complaints in last 365 days'}, xlabel='Date received', ylabel='Number of complaints'>

# %% [markdown]
# ### 13.Number of complaints for every category in different states

# %%
complaints.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
complaints['Product'].unique()
# Out:
# array(['Credit reporting, credit repair services, or other personal consumer reports',
#        'Credit card or prepaid card', 'Checking or savings account',
#        'Money transfer, virtual currency, or money service',
#        'Debt collection', 'Mortgage', 'Student loan',
#        'Payday loan, title loan, or personal loan',
#        'Vehicle loan or lease', 'Credit card', 'Credit reporting',
#        'Consumer Loan', 'Bank account or service', 'Payday loan',
#        'Money transfers', 'Prepaid card', 'Other financial service',
#        'Virtual currency'], dtype=object)

# %%
len(complaints['Product'].unique())
# Out:
# 18

# %%
categorical_complaints = complaints[['Complaint ID', 'Product', 'State']]

# %%
categorical_complaints.head()
# Out:
#    Complaint ID                                            Product State
# 0       6896105  Credit reporting, credit repair services, or o...    GA
# 1       6896026  Credit reporting, credit repair services, or o...    PA
# 2       6896030  Credit reporting, credit repair services, or o...    PA
# 3       6896035  Credit reporting, credit repair services, or o...    TX
# 4       6896060  Credit reporting, credit repair services, or o...    NY

# %%
categorical_complaints_gr = categorical_complaints.groupby(by=['State', 'Product']).agg('count')

# %%
categorical_complaints_gr.head(50)
# Out:
#                                                           Complaint ID
# State Product
# AA    Bank account or service                                        2
#       Checking or savings account                                    6
#       Credit card                                                    2
#       Credit card or prepaid card                                    3
#       Credit reporting, credit repair services, or ot...            20
#       Debt collection                                                5
#       Money transfer, virtual currency, or money service             3
#       Mortgage                                                      11
#       Student loan                                                   3
# AE    Bank account or service                                       33
#       Checking or savings account                                   43
#       Consumer Loan                                                 19
# ...

# %% [markdown]
# ### 14.Find complaints that was timely responded and simultaneously was disputed by consumer.

# %%
time_and_disputed_responses = complaints[['Complaint ID', 'Timely response?', 'Consumer disputed?']]

# %%
response_in_time = time_and_disputed_responses['Timely response?'] == 'Yes'

# %%
consumer_was_disputed = time_and_disputed_responses['Consumer disputed?'] == 'Yes'

# %%
time_and_disputed_responses = time_and_disputed_responses.loc[response_in_time & consumer_was_disputed]

# %%
time_and_disputed_responses.head()
# Out:
#        Complaint ID Timely response? Consumer disputed?
# 36514       2138120              Yes                Yes
# 36582       1641680              Yes                Yes
# 36607        440362              Yes                Yes
# 36959        818582              Yes                Yes
# 37090       1399035              Yes                Yes

# %% [markdown]
# #### How many was such complaints?

# %%
len(time_and_disputed_responses)
# Out:
# 145808

# %% [markdown]
# ### 15.Compare complaints description average length for every category

# %%
complaints_description = complaints[['Product', 'Consumer complaint narrative']]

# %%
complaints_description.head()
# Out:
#                                              Product  \
# 0  Credit reporting, credit repair services, or o...
# 1  Credit reporting, credit repair services, or o...
# 2  Credit reporting, credit repair services, or o...
# 3  Credit reporting, credit repair services, or o...
# 4  Credit reporting, credit repair services, or o...
#
#   Consumer complaint narrative
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %%
len(complaints_description)
# Out:
# 3585952

# %%
complaints_description = complaints_description.fillna('')

# %%
complaints_description.head()
# Out:
#                                              Product  \
# 0  Credit reporting, credit repair services, or o...
# 1  Credit reporting, credit repair services, or o...
# 2  Credit reporting, credit repair services, or o...
# 3  Credit reporting, credit repair services, or o...
# 4  Credit reporting, credit repair services, or o...
#
#   Consumer complaint narrative
# 0
# 1
# 2
# 3
# 4

# %%
complaints_description['Description length'] = complaints_description['Consumer complaint narrative'].str.len()

# %%
complaints_description.tail(10)
# Out:
#                                                    Product  \
# 3585942                                   Credit reporting
# 3585943                                      Consumer Loan
# 3585944                                           Mortgage
# 3585945                                   Credit reporting
# 3585946                                           Mortgage
# 3585947                            Bank account or service
# 3585948                                   Credit reporting
# 3585949                                           Mortgage
# 3585950                                           Mortgage
# 3585951  Credit reporting, credit repair services, or o...
#
#                               Consumer complaint narrative  Description length
# 3585942                                                                      0
# 3585943                                                                      0
# 3585944                                                                      0
# ...

# %%
del complaints_description['Consumer complaint narrative']

# %%
complaints_description.tail(10)
# Out:
#                                                    Product  Description length
# 3585942                                   Credit reporting                   0
# 3585943                                      Consumer Loan                   0
# 3585944                                           Mortgage                   0
# 3585945                                   Credit reporting                   0
# 3585946                                           Mortgage                 407
# 3585947                            Bank account or service                1076
# 3585948                                   Credit reporting                1090
# 3585949                                           Mortgage                   0
# 3585950                                           Mortgage                   0
# 3585951  Credit reporting, credit repair services, or o...                   0

# %%
complaints_description_gr = complaints_description.groupby('Product').agg('mean')

# %%
complaints_description_gr['Description length'] = complaints_description_gr['Description length'].round(0)

# %%
complaints_description_gr
# Out:
#                                                     Description length
# Product
# Bank account or service                                          215.0
# Checking or savings account                                      520.0
# Consumer Loan                                                    332.0
# Credit card                                                      238.0
# Credit card or prepaid card                                      627.0
# Credit reporting                                                 169.0
# Credit reporting, credit repair services, or ot...               308.0
# Debt collection                                                  409.0
# Money transfer, virtual currency, or money service               689.0
# Money transfers                                                  322.0
# Mortgage                                                         455.0
# Other financial service                                          340.0
# ...

# %% [markdown]
# #### Which category has the biggest average length of description?

# %%
complaints_description_gr.loc[complaints_description_gr.idxmax()]
# Out:
#                   Description length
# Product
# Virtual currency               836.0

# %% [markdown]
# #### Which category has the smallest average length of description?

# %%
complaints_description_gr.loc[complaints_description_gr.idxmin()]
# Out:
#                   Description length
# Product
# Credit reporting               169.0
